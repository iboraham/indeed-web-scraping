# %%
import pandas as pd
import numpy as np

df=pd.read_csv('df_broad.csv')
df
# Out:
#                                                   Title         Location  \
# 0                                        Data Scientist          Bromley
# 1     Biostatistician / Data Scientist - Innovative ...           London
# 2                                        Data Scientist           London
# 3                                 Junior Data Scientist           London
# 4                                   Data Scientist Lead           London
# 5                  Data Scientist - Talent Pool (m/f/d)  London EC4M 9AF
# 6                               Graduate Data Scientist           London
# 7                                     HR Data Scientist           London
# 8      Data Scientist - Fully Remote Working Available!  London SW1X 7QL
# 9                               Insights Data Scientist           London
# 10                           Data Scientist – Team Lead           London
# 11                                       Data Scientist           London
# ...

# %%
df = df.drop_duplicates(keep='first').reset_index(drop=True)
df
# Out:
#                                                   Title            Location  \
# 0                                        Data Scientist             Bromley
# 1     Biostatistician / Data Scientist - Innovative ...              London
# 2                                        Data Scientist              London
# 3                                 Junior Data Scientist              London
# 4                                   Data Scientist Lead              London
# 5                  Data Scientist - Talent Pool (m/f/d)     London EC4M 9AF
# 6                               Graduate Data Scientist              London
# 7                                     HR Data Scientist              London
# 8      Data Scientist - Fully Remote Working Available!     London SW1X 7QL
# 9                               Insights Data Scientist              London
# 10                           Data Scientist – Team Lead              London
# ...

# %%
df_dataScientist = df[df.Title.str.contains('Data Scien')]
df_dataScientist

# %%
line=df_dataScientist.Description.str.cat(sep=';')
line
# Out:
# 'Data Scientist - Contract - £competitive rate\nOur client are an innovative and dynamic company and are currently looking for Data Scientist to join their team on an initial 6 month basis.\nAs a Data Scientist you will be working on an existing market-validated product, with a prioritised backlog of issues groomed and ready for you to hit the ground running from day one.\nRequirements:\nHas strong experience with Python\nWorking knowledge of C++\nHas at least 2+ years of commercial experience\nIf you are interested in the above role, please apply!;Job Description\n\nWhere you’ll fit in & what our team goals are….\n\nIn this role you will be responsible for developing, documenting, testing, modifying, and maintaining software within the Columbia Threadneedle Investments Data Science Team. You will provide technical assistance and guidance to other members of the Investments Data Science Team, and work with different investment teams to design and implement software to support and enh
# ...
